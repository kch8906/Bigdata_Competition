# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.font_manager as fm

[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df_01 = pd.read_csv('../bigdata/LPOINT_BIG_COMP/LPOINT_BIG_COMP_01_DEMO.csv')
df_02 = pd.read_csv('../bigdata/LPOINT_BIG_COMP/LPOINT_BIG_COMP_02_PDDE.csv')
df_03 = pd.read_csv('../bigdata/LPOINT_BIG_COMP/LPOINT_BIG_COMP_03_COP_U.csv')
df_04 = pd.read_csv('../bigdata/LPOINT_BIG_COMP/LPOINT_BIG_COMP_04_PD_CLAC.csv')
df_05 = pd.read_csv('../bigdata/LPOINT_BIG_COMP/LPOINT_BIG_COMP_05_BR.csv')
df_06 = pd.read_csv('../bigdata/LPOINT_BIG_COMP/LPOINT_BIG_COMP_06_LPAY.csv')

# %%
df_merge_01_02 = pd.merge(df_02, df_01, how='inner', on='cust')
df_merge_01_02 = df_merge_01_02.fillna(-999)
df_merge_01_02
# Out:
#                cust        rct_no  chnl_dv cop_c     br_c    pd_c     de_dt  \
# 0        M430112881  A01000001113        1   A01  A010039  PD0290  20210101
# 1        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 2        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 3        M430112881  A01000004946        1   A01  A010039  PD0290  20210101
# 4        M430112881  A01000005297        1   A01  A010039  PD1692  20210101
# ...             ...           ...      ...   ...      ...     ...       ...
# 4381738  M498069014  E06052019590        2   A06     -999  PD0507  20211227
# 4381739  M498069014  E06052019590        2   A06     -999  PD0507  20211227
# 4381740  M498069014  E06052019590        2   A06     -999  PD0507  20211227
# 4381741  M498069014  E06052019590        2   A06     -999  PD0507  20211227
# 4381742  M866900192  E06052003637        2   A06     -999  PD0969  20211231
#
#          de_hr    buy_am  buy_ct ma_fem_dv ages zon_hlv
# 0           10   15000.0       1        여성  50대     Z17
# 1           10   19000.0       1        여성  50대     Z17
# 2           10   19000.0       1        여성  50대     Z17
# 3           10   19000.0       1        여성  50대     Z17
# 4           10    9900.0       1        여성  50대     Z17
# ...        ...       ...     ...       ...  ...     ...
# 4381738     16  100000.0       1        여성  40대     Z14
# 4381739     16  100000.0       1        여성  40대     Z14
# 4381740     16  100000.0       1        여성  40대     Z14
# 4381741     16  100000.0       1        여성  40대     Z14
# 4381742     13   80100.0       1        여성  50대     Z10
#
# [4381743 rows x 13 columns]

# %%
import random

def random_choice(zon_hlv, cop_c):
    filt = df_05['zon_hlv'] == zon_hlv
    filt2 = df_05['cop_c'] == cop_c
    res = df_05[filt][filt2]
    br_c_list = []

    try:        
        for i in range(len(res['br_c'])):
            test = res['br_c'].reset_index()
            ans = test['br_c'][i]
            br_c_list.append(ans)

        random_store = random.choice(br_c_list)

        return random_store

    except: IndexError

# %%
for i in range(len(df_merge_01_02)):
    if df_merge_01_02.loc[i, 'br_c'] == -999:    
        zon_hlv = df_merge_01_02.loc[i]['zon_hlv']
        cop_c = df_merge_01_02.loc[i]['cop_c']
        df_merge_01_02.loc[i, 'br_c'] = random_choice(zon_hlv, cop_c)

# %%
import multiprocessing as mp
import numpy as np
num_cores = 6
def parallel_dataframe(df, func):
    global num_cores
    df_split = np.array_split(df, num_cores)
    pool = mp.Pool(num_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df

# %%
def multiply_columns(df):
    df['br_c'] = df[['br_c', 'zon_hlv', 'cop_c']].apply(lambda x : random_choice(x['zon_hlv'], x['cop_c']))
    return df

# %%
res = df_merge_01_02[df_merge_01_02['br_c'] == -999]
res
# for i in res.index:
#     if res.loc[i, 'br_c'] == -999:    
#         zon_hlv = res.loc[i]['zon_hlv']
#         cop_c = res.loc[i]['cop_c']
#         res.loc[i, 'br_c'] = random_choice(zon_hlv, cop_c)
# Out:
#                cust        rct_no  chnl_dv cop_c  br_c    pd_c     de_dt  \
# 418      M646853852  E01001415268        2   A01  -999  PD0025  20210223
# 419      M646853852  E01001416273        2   A01  -999  PD0025  20210223
# 420      M646853852  E01001417672        2   A01  -999  PD0025  20210223
# 766      M646853852  E06024223441        2   A06  -999  PD1736  20210403
# 767      M646853852  E06029401213        2   A06  -999  PD0124  20210419
# ...             ...           ...      ...   ...   ...     ...       ...
# 4381738  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381739  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381740  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381741  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381742  M866900192  E06052003637        2   A06  -999  PD0969  20211231
#
#          de_hr     buy_am  buy_ct ma_fem_dv ages zon_hlv
# 418         21  1761000.0       1        여성  40대     Z13
# 419         21  1761000.0       1        여성  40대     Z13
# 420         21   416000.0       1        여성  40대     Z13
# 766         14    11900.0       1        여성  40대     Z13
# 767         17   185800.0       2        여성  40대     Z13
# ...        ...        ...     ...       ...  ...     ...
# 4381738     16   100000.0       1        여성  40대     Z14
# 4381739     16   100000.0       1        여성  40대     Z14
# 4381740     16   100000.0       1        여성  40대     Z14
# 4381741     16   100000.0       1        여성  40대     Z14
# 4381742     13    80100.0       1        여성  50대     Z10
#
# [428501 rows x 13 columns]

# %%
res = res.apply(random_choice(zon_hlv=res['zon_hlv'], cop_c=res['cop_c']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Changhyun\Desktop\Bigdata_Competition\0714.ipynb 셀 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000046?line=0'>1</a> res = res.apply(random_choice(zon_hlv=res['zon_hlv'], cop_c=res['cop_c']))
#
# c:\Users\Changhyun\Desktop\Bigdata_Competition\0714.ipynb 셀 12 in random_choice(zon_hlv, cop_c)
#       <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000046?line=2'>3</a> def random_choice(zon_hlv, cop_c):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000046?line=3'>4</a>     filt = df_05['zon_hlv'] == zon_hlv
#       <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000046?line=4'>5</a>     filt2 = df_05['cop_c'] == cop_c
#       <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000046?line=5'>6</a>     res = df_05[filt][filt2]
#
# File c:\Users\Changhyun\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File c:\Users\Changhyun\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\Changhyun\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\series.py:5617, in Series._cmp_method(self, other, op)
#    5614 res_name = ops.get_op_result_name(self, other)
#    5616 if isinstance(other, Series) and not self._indexed_same(other):
# -> 5617     raise ValueError("Can only compare identically-labeled Series objects")
#    5619 lvalues = self._values
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
res.loc[418, 'br_c'] = 1
res
# Out:
#                cust        rct_no  chnl_dv cop_c  br_c    pd_c     de_dt  \
# 418      M646853852  E01001415268        2   A01     1  PD0025  20210223
# 419      M646853852  E01001416273        2   A01  -999  PD0025  20210223
# 420      M646853852  E01001417672        2   A01  -999  PD0025  20210223
# 766      M646853852  E06024223441        2   A06  -999  PD1736  20210403
# 767      M646853852  E06029401213        2   A06  -999  PD0124  20210419
# ...             ...           ...      ...   ...   ...     ...       ...
# 4381738  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381739  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381740  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381741  M498069014  E06052019590        2   A06  -999  PD0507  20211227
# 4381742  M866900192  E06052003637        2   A06  -999  PD0969  20211231
#
#          de_hr     buy_am  buy_ct ma_fem_dv ages zon_hlv
# 418         21  1761000.0       1        여성  40대     Z13
# 419         21  1761000.0       1        여성  40대     Z13
# 420         21   416000.0       1        여성  40대     Z13
# 766         14    11900.0       1        여성  40대     Z13
# 767         17   185800.0       2        여성  40대     Z13
# ...        ...        ...     ...       ...  ...     ...
# 4381738     16   100000.0       1        여성  40대     Z14
# 4381739     16   100000.0       1        여성  40대     Z14
# 4381740     16   100000.0       1        여성  40대     Z14
# 4381741     16   100000.0       1        여성  40대     Z14
# 4381742     13    80100.0       1        여성  50대     Z10
#
# [428501 rows x 13 columns]

# %%
random_choice('Z17', 'A06')

# %%
test = df_merge_01_02[['br_c', 'zon_hlv']]
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Changhyun\Desktop\Bigdata_Competition\0714.ipynb 셀 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000031?line=0'>1</a> test = df_merge_01_02[['br_c', 'zon_hlv']]
#       <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000031?line=1'>2</a> test
#
# NameError: name 'df_merge_01_02' is not defined

# %%
test = test.fillna(-999)
test[test['br_c'] == -999]
# Out:
#          br_c zon_hlv
# 418      -999     Z13
# 419      -999     Z13
# 420      -999     Z13
# 766      -999     Z13
# 767      -999     Z13
# ...       ...     ...
# 4381738  -999     Z14
# 4381739  -999     Z14
# 4381740  -999     Z14
# 4381741  -999     Z14
# 4381742  -999     Z10
#
# [428501 rows x 2 columns]

# %%
sns.countplot(x='zon_hlv', data=test)
# Out:
# <AxesSubplot:xlabel='zon_hlv', ylabel='count'>

# %%
filt = df_05['zon_hlv'] == 'Z13'
filt2 = df_05['cop_c'] == 'A01'
res = df_05[filt][filt2]
res
# Out:
#        br_c cop_c zon_hlv zon_mcls
# 5   A010006   A01     Z13   Z13003
# 15  A010016   A01     Z13   Z13005
# 24  A010025   A01     Z13   Z13001

# %%
a = 'Z14'
b = 'A06'
random_choice('Z17', 'A06')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Changhyun\Desktop\Bigdata_Competition\0714.ipynb 셀 12 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000032?line=0'>1</a> a = 'Z14'
#       <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000032?line=1'>2</a> b = 'A06'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000032?line=2'>3</a> random_choice('Z17', 'A06')
#
# c:\Users\Changhyun\Desktop\Bigdata_Competition\0714.ipynb 셀 12 in random_choice(zon_hlv, cop_c)
#       <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000032?line=8'>9</a>     ans = test['br_c'][i]
#      <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000032?line=9'>10</a>     br_c_list.append(ans)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000032?line=11'>12</a> random_store = random.choice(br_c_list)
#      <a href='vscode-notebook-cell:/c%3A/Users/Changhyun/Desktop/Bigdata_Competition/0714.ipynb#ch0000032?line=13'>14</a> return random_store
#
# File c:\Users\Changhyun\AppData\Local\Programs\Python\Python38\lib\random.py:290, in Random.choice(self, seq)
#     288     i = self._randbelow(len(seq))
#     289 except ValueError:
# --> 290     raise IndexError('Cannot choose from an empty sequence') from None
#     291 return seq[i]
#
# IndexError: Cannot choose from an empty sequence
