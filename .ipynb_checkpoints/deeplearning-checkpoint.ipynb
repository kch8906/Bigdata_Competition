# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
import random
from tqdm import tqdm
warnings.filterwarnings('ignore')

# %%
import matplotlib.font_manager as fm

[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df_01 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_01_DEMO.csv')
df_02 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_02_PDDE.csv')
df_03 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_03_COP_U.csv')
df_04 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_04_PD_CLAC.csv')
df_05 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_05_BR.csv')
df_06 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_06_LPAY.csv')

# %%
df_02 = df_02[df_02['chnl_dv'] == 1]

# %%
df_02.drop(columns=['buy_am', 'de_dt', 'rct_no', 'chnl_dv'], axis=1, inplace=True)

# %%
df_merge_02_04 = pd.merge(df_02, df_04, on='pd_c')
df_merge_02_04
# Out:
#                cust cop_c     br_c    pd_c  de_hr  buy_ct    pd_nm  \
# 0        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 1        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 2        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 3        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 4        M506355556   A01  A010032  PD0290     15       1    남성티셔츠
# ...             ...   ...      ...     ...    ...     ...      ...
# 3953237  M033482606   A05  A050003  PD0075     20       1  혈당계/혈압계
# 3953238  M489266563   A05  A050426  PD1221     15       1  청소기/광택기
# 3953239  M296090374   A05  A050260  PD0543     11       1      이발기
# 3953240  M560002381   A05  A050039  PD0543     12       1      이발기
# 3953241  M203801534   A05  A050178  PD0281     18       1     기타보험
#
#         clac_hlv_nm clac_mcls_nm
# 0              남성의류       남성의류상의
# 1              남성의류       남성의류상의
# 2              남성의류       남성의류상의
# 3              남성의류       남성의류상의
# 4              남성의류       남성의류상의
# ...             ...          ...
# 3953237        건강용품       건강측정용품
# 3953238       자동차용품         세차용품
# 3953239     생활/주방가전        이미용가전
# 3953240     생활/주방가전        이미용가전
# 3953241    금융/보험서비스           보험
#
# [3953242 rows x 9 columns]

# %% [markdown]
# ### 상품 상위 5개 추출

# %%
def frequency_product(cust, df_merge_02_04):
    person_id = cust
    pd_c = df_merge_02_04[df_merge_02_04['cust'] == person_id][['clac_hlv_nm', 'buy_ct']]
    pd_c = pd_c.groupby('clac_hlv_nm')['buy_ct'].sum().reset_index()
    pd_c = pd_c.sort_values(by='buy_ct', ascending=False, ignore_index=True)
    freq_product = []
    for i in range(5):
        try:
            freq_product.append(pd_c['clac_hlv_nm'][i])

        except: KeyError
            
    return freq_product

# %%
frequency_product('M430112881', df_merge_02_04)
# Out:
# ['채소', '냉장식품', '수산물', '유제품', '음료']

# %%
df_01['freq_product'] = df_01.apply(lambda x : frequency_product(x['cust'], df_merge_02_04), axis=1)

# %% [markdown]
# ### 평점 변환

# %%
def convert_rating(cust, clac_hlv_nm, df):
    
    person_id = cust    
    try:
        pd_c = df[df['cust'] == cust][['clac_hlv_nm', 'buy_ct']]
        pd_c = pd_c.groupby('clac_hlv_nm')['buy_ct'].sum().reset_index()
        pd_c = pd_c.sort_values(by='buy_ct', ascending=False, ignore_index=True)

        pd_c['buy_ct'] = (pd_c['buy_ct'] - pd_c['buy_ct'].min()) / (pd_c['buy_ct'].max() - pd_c['buy_ct'].min())
        pd_c['buy_ct'][0] = random.uniform(0.85, 1.01) 
        pd_c['buy_ct'] = np.round(pd_c['buy_ct'], 2) * 10

        res = float(pd_c[pd_c['clac_hlv_nm'] == clac_hlv_nm]['buy_ct'])
        
    except: ValueError
        
    return res

# %%
res = convert_rating(df_merge_02_04['cust'][10], df_merge_02_04['clac_hlv_nm'][10], df_merge_02_04)
res
# Out:
# 3.8

# %%
df_merge_02_04['ratings'] = df_merge_02_04.apply(lambda x : convert_rating(x['cust'], x['clac_hlv_nm'], df_merge_02_04), axis=1)

# %% [markdown]
# ### 멀티프로세싱

# %%
import multiprocessing as mp

num_cores = mp.cpu_count()

def parallel_dataframe(df, func):
    global num_cores
    df_split = np.array_split(df, num_cores)
    pool = mp.Pool(num_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    
    return df

# %%
tqdm.pandas()
def make_ratings(data):
    data['ratings'] = data.progress_apply(lambda x : convert_rating(x['cust'], x['clac_hlv_nm'], data), axis=1)
    return data

# %%
df = parallel_dataframe(df_merge_02_04, make_ratings)
# Out:
# 100%|█████████████████████████████████| 658874/658874 [9:05:39<00:00, 20.12it/s]
#  98%|████████████████████████████████▏| 643425/658874 [9:42:51<13:43, 18.75it/s]
# 100%|█████████████████████████████████| 658874/658874 [9:55:08<00:00, 18.45it/s]
# 100%|████████████████████████████████| 658873/658873 [10:11:36<00:00, 17.95it/s]
# 100%|████████████████████████████████| 658873/658873 [10:18:12<00:00, 17.76it/s]
# 100%|████████████████████████████████| 658874/658874 [10:28:50<00:00, 17.46it/s]

# %%
df.to_csv('df_merge_02_04_ratings.csv')

# %%
df['ratings'].isna().sum()
# Out:
# 13256

# %%
df_test = df[df['ratings'].isna()]
df_test
# Out:
#                cust cop_c     br_c    pd_c  de_hr  buy_ct      pd_nm  \
# 282      M260927455   A01  A010021  PD0290     15       1      남성티셔츠
# 1342     M403286666   A01  A010024  PD0290     16       1      남성티셔츠
# 1346     M403286666   A01  A010024  PD0290     17       1      남성티셔츠
# 2519     M560023501   A01  A010002  PD0290     10       1      남성티셔츠
# 3040     M614062136   A01  A010045  PD0290     14       1      남성티셔츠
# ...             ...   ...      ...     ...    ...     ...        ...
# 3952965  M081494913   A05  A050130  PD0552     11       1     전기프라이팬
# 3952974  M784453498   A05  A050238  PD0990     17       1  TV장식장/거치대
# 3953035  M224574767   A05  A050274  PD1004     19       1        컴팩트
# 3953093  M518148689   A05  A050267  PD0998     15       1    CDP/카세트
# 3953213  M603121404   A05  A050227  PD0540     20       1        고데기
#
#         clac_hlv_nm clac_mcls_nm  ratings
# 282            남성의류       남성의류상의      NaN
# 1342           남성의류       남성의류상의      NaN
# 1346           남성의류       남성의류상의      NaN
# 2519           남성의류       남성의류상의      NaN
# 3040           남성의류       남성의류상의      NaN
# ...             ...          ...      ...
# 3952965     생활/주방가전         주방가전      NaN
# 3952974     영상/음향가전           TV      NaN
# 3953035     영상/음향가전      카메라/캠코더      NaN
# 3953093     영상/음향가전          오디오      NaN
# 3953213     생활/주방가전        이미용가전      NaN
#
# [13256 rows x 10 columns]

# %%
df.dropna(inplace=True)

# %%
df_others = parallel_dataframe(df_test, make_ratings)
df_others
# Out:
# 100%|█████████████████████████████████████▉| 2203/2209 [00:10<00:00, 224.49it/s]
# 100%|██████████████████████████████████████| 2209/2209 [00:10<00:00, 220.04it/s]
# 100%|██████████████████████████████████████| 2209/2209 [00:10<00:00, 216.27it/s]
# 100%|██████████████████████████████████████| 2209/2209 [00:10<00:00, 213.36it/s]
# 100%|██████████████████████████████████████| 2210/2210 [00:10<00:00, 212.11it/s]
# 100%|██████████████████████████████████████| 2210/2210 [00:10<00:00, 211.69it/s]
#                cust cop_c     br_c    pd_c  de_hr  buy_ct      pd_nm  \
# 282      M260927455   A01  A010021  PD0290     15       1      남성티셔츠
# 1342     M403286666   A01  A010024  PD0290     16       1      남성티셔츠
# 1346     M403286666   A01  A010024  PD0290     17       1      남성티셔츠
# 2519     M560023501   A01  A010002  PD0290     10       1      남성티셔츠
# 3040     M614062136   A01  A010045  PD0290     14       1      남성티셔츠
# ...             ...   ...      ...     ...    ...     ...        ...
# 3952965  M081494913   A05  A050130  PD0552     11       1     전기프라이팬
# 3952974  M784453498   A05  A050238  PD0990     17       1  TV장식장/거치대
# 3953035  M224574767   A05  A050274  PD1004     19       1        컴팩트
# 3953093  M518148689   A05  A050267  PD0998     15       1    CDP/카세트
# 3953213  M603121404   A05  A050227  PD0540     20       1        고데기
#
#         clac_hlv_nm clac_mcls_nm  ratings
# 282            남성의류       남성의류상의      9.1
# 1342           남성의류       남성의류상의      8.6
# 1346           남성의류       남성의류상의      9.5
# 2519           남성의류       남성의류상의      9.2
# 3040           남성의류       남성의류상의      9.7
# ...             ...          ...      ...
# 3952965     생활/주방가전         주방가전      9.8
# 3952974     영상/음향가전           TV      8.8
# 3953035     영상/음향가전      카메라/캠코더      9.3
# 3953093     영상/음향가전          오디오      9.1
# 3953213     생활/주방가전        이미용가전      NaN
#
# [13256 rows x 10 columns]

# %%
df_others['ratings'].isna().sum()
# Out:
# 4083

# %%
df = pd.concat([df, df_others])
df.dropna(inplace=True)

# %%
df
# Out:
#           cust cop_c  br_c    pd_c  de_hr  buy_ct      pd_nm clac_hlv_nm  \
# 0        11214   A01    38  PD0290     10       1      남성티셔츠        남성의류
# 1        11214   A01    38  PD0290     10       1      남성티셔츠        남성의류
# 2        11214   A01    38  PD0290     10       1      남성티셔츠        남성의류
# 3        11214   A01    38  PD0290     10       1      남성티셔츠        남성의류
# 4        13236   A01    31  PD0290     15       1      남성티셔츠        남성의류
# ...        ...   ...   ...     ...    ...     ...        ...         ...
# 3952940   2972   A05  6707  PD0552     16       1     전기프라이팬     생활/주방가전
# 3952965   2132   A05  6443  PD0552     11       1     전기프라이팬     생활/주방가전
# 3952974  20503   A05  6551  PD0990     17       1  TV장식장/거치대     영상/음향가전
# 3953035   5880   A05  6587  PD1004     19       1        컴팩트     영상/음향가전
# 3953093  13522   A05  6580  PD0998     15       1    CDP/카세트     영상/음향가전
#
#         clac_mcls_nm  ratings
# 0             남성의류상의      5.0
# 1             남성의류상의      5.0
# 2             남성의류상의      5.0
# 3             남성의류상의      5.0
# 4             남성의류상의      9.7
# ...              ...      ...
# 3952940         주방가전      9.0
# 3952965         주방가전      9.8
# 3952974           TV      8.8
# 3953035      카메라/캠코더      9.3
# 3953093          오디오      9.1
#
# [3958332 rows x 10 columns]

# %%
df.to_csv('fill_isna_df.csv')

# %%
df_04
# Out:
#         pd_c     pd_nm clac_hlv_nm clac_mcls_nm
# 0     PD0001        소파          가구         거실가구
# 1     PD0002   스툴/리빙의자          가구         거실가구
# 2     PD0003        탁자          가구         거실가구
# 3     PD0004   장식장/진열장          가구         거실가구
# 4     PD0005      기타가구          가구         기타가구
# ...      ...       ...         ...          ...
# 1928  PD1929      여성향수    화장품/뷰티케어           향수
# 1929  PD1930      남성향수    화장품/뷰티케어           향수
# 1930  PD1931    남녀공용향수    화장품/뷰티케어           향수
# 1931  PD1932    남성향수세트    화장품/뷰티케어           향수
# 1932  PD1933  남녀공용향수세트    화장품/뷰티케어           향수
#
# [1933 rows x 4 columns]

# %% [markdown]
# ### LabelEncoder
# - cust, br_c

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

encoder = LabelEncoder()

columns = ['cust', 'clac_hlv_nm']

for i in columns:
    df[i] = encoder.fit_transform(df[i])

# %%
df_04['clac_hlv_nm'] = encoder.fit_transform(df_04['clac_hlv_nm'])

# %% [markdown]
# ## Deeplearning
# - dot 기반

# %% [markdown]
# ### DATA, PRODUCT 데이터 나누기

# %%
data = df[['cust', 'clac_hlv_nm', 'ratings']]
data
# Out:
#           cust  clac_hlv_nm  ratings
# 0        11214           12      5.0
# 1        11214           12      5.0
# 2        11214           12      5.0
# 3        11214           12      5.0
# 4        13236           12      9.7
# ...        ...          ...      ...
# 3952940   2972           23      9.0
# 3952965   2132           23      9.8
# 3952974  20503           35      8.8
# 3953035   5880           35      9.3
# 3953093  13522           35      9.1
#
# [3958332 rows x 3 columns]

# %%
product = df_04
product
# Out:
#         pd_c     pd_nm  clac_hlv_nm clac_mcls_nm
# 0     PD0001        소파            0         거실가구
# 1     PD0002   스툴/리빙의자            0         거실가구
# 2     PD0003        탁자            0         거실가구
# 3     PD0004   장식장/진열장            0         거실가구
# 4     PD0005      기타가구            0         기타가구
# ...      ...       ...          ...          ...
# 1928  PD1929      여성향수           59           향수
# 1929  PD1930      남성향수           59           향수
# 1930  PD1931    남녀공용향수           59           향수
# 1931  PD1932    남성향수세트           59           향수
# 1932  PD1933  남녀공용향수세트           59           향수
#
# [1933 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2, random_state=52)
print(train.shape, test.shape)
# Out:
# (3166665, 3) (791667, 3)

# %%
number_of_unique_user = len(data['cust'].unique())
number_of_unique_product_id = len(data['clac_hlv_nm'].unique())
print(number_of_unique_user, number_of_unique_product_id)
# Out:
# 26027 60

# %% [markdown]
# ### 1. Dot product

# %%
from tensorflow.keras.layers import Input, Embedding, Flatten, Dot, Dense, Concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import plot_model

# %%
product_input = Input(shape=(1,), name='product_input_layer')
user_input = Input(shape=(1,), name='user_input_layer')

product_embedding_layer = Embedding(number_of_unique_product_id + 1, 10, name='product_embedding_layer')
user_embedding_layer = Embedding(number_of_unique_user + 1, 10, name='user_embedding_layer')

product_vector_layer = Flatten(name='product_vector_layer')
user_vector_layer = Flatten(name='user_vector_layer')

dot_result_layer = Dot(name='dot_vector_layer', axes = 1)

# %%
product_embedding = product_embedding_layer(product_input)
user_embedding = user_embedding_layer(user_input)

product_vector = product_vector_layer(product_embedding)
user_vector = user_vector_layer(user_embedding)

dot_result = dot_result_layer([product_vector, user_vector])
model = Model(inputs=[user_input, product_input], outputs=dot_result)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  product_input_layer (InputLaye  [(None, 1)]         0           []
#  r)
#
#  user_input_layer (InputLayer)  [(None, 1)]          0           []
#
#  product_embedding_layer (Embed  (None, 1, 10)       610         ['product_input_layer[0][0]']
#  ding)
#
#  user_embedding_layer (Embeddin  (None, 1, 10)       260280      ['user_input_layer[0][0]']
#  g)
#
#  product_vector_layer (Flatten)  (None, 10)          0           ['product_embedding_layer[0][0]']
#
#  user_vector_layer (Flatten)    (None, 10)           0           ['user_embedding_layer[0][0]']
#
#  dot_vector_layer (Dot)         (None, 1)            0           ['product_vector_layer[0][0]',
#                                                                   'user_vector_layer[0][0]']
#
# ==================================================================================================
# Total params: 260,890
# Trainable params: 260,890
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# %%
history = model.fit([train['cust'], train['clac_hlv_nm']], train['ratings'], epochs=20, batch_size=256, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 9896/9896 [==============================] - 17s 2ms/step - loss: 15.9284 - mse: 15.9284 - val_loss: 11.8418 - val_mse: 11.8418
# Epoch 2/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 11.3277 - mse: 11.3277 - val_loss: 10.7327 - val_mse: 10.7327
# Epoch 3/20
# 9896/9896 [==============================] - 17s 2ms/step - loss: 9.7252 - mse: 9.7252 - val_loss: 9.2863 - val_mse: 9.2863
# Epoch 4/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 8.4125 - mse: 8.4125 - val_loss: 8.5916 - val_mse: 8.5916
# Epoch 5/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 7.7696 - mse: 7.7696 - val_loss: 8.3522 - val_mse: 8.3522
# Epoch 6/20
# 9896/9896 [==============================] - 19s 2ms/step - loss: 7.4909 - mse: 7.4909 - val_loss: 8.2720 - val_mse: 8.2720
# Epoch 7/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 7.3425 - mse: 7.3425 - val_loss: 8.2348 - val_mse: 8.2348
# Epoch 8/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 7.2459 - mse: 7.2459 - val_loss: 8.2152 - val_mse: 8.2152
# Epoch 9/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 7.1769 - mse: 7.1769 - val_loss: 8.2044 - val_mse: 8.2044
# Epoch 10/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 7.1226 - mse: 7.1226 - val_loss: 8.1997 - val_mse: 8.1997
# Epoch 11/20
# 9896/9896 [==============================] - 19s 2ms/step - loss: 7.0797 - mse: 7.0797 - val_loss: 8.1929 - val_mse: 8.1929
# Epoch 12/20
# 9896/9896 [==============================] - 19s 2ms/step - loss: 7.0437 - mse: 7.0437 - val_loss: 8.1896 - val_mse: 8.1896
# Epoch 13/20
# 9896/9896 [==============================] - 19s 2ms/step - loss: 7.0142 - mse: 7.0142 - val_loss: 8.1815 - val_mse: 8.1815
# Epoch 14/20
# 9896/9896 [==============================] - 18s 2ms/step - loss: 6.9881 - mse: 6.9881 - val_loss: 8.1843 - val_mse: 8.1843
# Epoch 15/20
# 9896/9896 [==============================] - 19s 2ms/step - loss: 6.9653 - mse: 6.9653 - val_loss: 8.1839 - val_mse: 8.1839
# Epoch 16/20
# 8761/9896 [=========================>....] - ETA: 1s - loss: 6.9260 - mse: 6.9260
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 history = model.fit([train['cust'], train['clac_hlv_nm']], train['ratings'], epochs=20, batch_size=256, validation_split=0.2, verbose=1)
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/keras/engine/training.py:1216, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1209 with tf.profiler.experimental.Trace(
#    1210     'train',
#    1211     epoch_num=epoch,
#    1212     step_num=step,
#    1213     batch_size=batch_size,
#    1214     _r=1):
#    1215   callbacks.on_train_batch_begin(step)
# -> 1216   tmp_logs = self.train_function(iterator)
#    1217   if data_handler.should_sync:
#    1218     context.async_wait()
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:942, in Function._call(self, *args, **kwds)
#     939   self._lock.release()
#     940   # In this case we have created variables on the first call, so we run the
#     941   # defunned version which is guaranteed to never create variables.
# --> 942   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943 elif self._stateful_fn is not None:
#     944   # Release the lock early so that multiple threads can perform the call
#     945   # in parallel.
#     946   self._lock.release()
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:3130, in Function.__call__(self, *args, **kwargs)
#    3127 with self._lock:
#    3128   (graph_function,
#    3129    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130 return graph_function._call_flat(
#    3131     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1959, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1955 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1956 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1957     and executing_eagerly):
#    1958   # No tape is watching; skip to running the function.
# -> 1959   return self._build_call_outputs(self._inference_function.call(
#    1960       ctx, args, cancellation_manager=cancellation_manager))
#    1961 forward_backward = self._select_forward_and_backward_functions(
#    1962     args,
#    1963     possible_gradient_type,
#    1964     executing_eagerly)
#    1965 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/tensorflow/python/eager/function.py:598, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     596 with _InterpolateFunctionError(self):
#     597   if cancellation_manager is None:
# --> 598     outputs = execute.execute(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#     601         inputs=args,
#     602         attrs=attrs,
#     603         ctx=ctx)
#     604   else:
#     605     outputs = execute.execute_with_cancellation(
#     606         str(self.signature.name),
#     607         num_outputs=self._num_outputs,
#    (...)
#     610         ctx=ctx,
#     611         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/envs/machine_TF2/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:58, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56 try:
#      57   ctx.ensure_initialized()
# ---> 58   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                       inputs, attrs, num_outputs)
#      60 except core._NotOkStatusException as e:
#      61   if name is not None:
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'])
plt.xlabel('epochs')
plt.ylabel('training error')
# Out:
# Text(0, 0.5, 'training error')
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
