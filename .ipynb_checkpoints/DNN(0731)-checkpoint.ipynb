# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
import random
from tqdm import tqdm
warnings.filterwarnings('ignore')
tqdm.pandas()

# %%
import matplotlib.font_manager as fm

[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
plt.rcParams['font.family'] = 'Nanum'

# %%
df_01 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_01_DEMO.csv')
df_02 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_02_PDDE.csv')
df_03 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_03_COP_U.csv')
df_04 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_04_PD_CLAC.csv')
df_05 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_05_BR.csv')
df_06 = pd.read_csv('../dataset/LPOINT_BIG_COMP/LPOINT_BIG_COMP_06_LPAY.csv')

# %%
df_03.drop(columns=['rct_no', 'vst_dt'], axis=1, inplace=True)

# %%
df_03['buy_am'].describe()
# Out:
# count    2.483040e+05
# mean     2.013066e+04
# std      2.430121e+05
# min      1.000000e+00
# 25%      5.000000e+03
# 50%      9.000000e+03
# 75%      1.580000e+04
# max      7.009200e+07
# Name: buy_am, dtype: float64

# %%
def categoricalBuy(data):
    res = 0
    
    if data < 1000:
        res = 0
    elif data >= 1000 and data < 9000:
        res = 1
    elif data >= 9000 and data < 15800:
        res = 2
    else:
        res = 3
        
    return res

# %%
df_03['buy_am'] = df_03.progress_apply(lambda x : categoricalBuy(x['buy_am']), axis=1)
# Out:
# 100%|███████████████████████████████| 248304/248304 [00:01<00:00, 152002.12it/s]

# %%
sns.countplot(x='buy_am', data=df_03)
# Out:
# <AxesSubplot:xlabel='buy_am', ylabel='count'>
# findfont: Font family ['Nanum'] not found. Falling back to DejaVu Sans.

# %%
from preprocessing import parallel_dataframe, convertRatingCop, copMakeRatings

df = parallel_dataframe(df_03, copMakeRatings, cores=6)
# Out:
# 100%|████████████████████████████████████| 41384/41384 [02:29<00:00, 276.82it/s]
# 100%|████████████████████████████████████| 41384/41384 [02:29<00:00, 276.33it/s]
# 100%|████████████████████████████████████| 41384/41384 [02:29<00:00, 276.27it/s]
# 100%|████████████████████████████████████| 41384/41384 [02:30<00:00, 274.86it/s]
# 100%|████████████████████████████████████| 41384/41384 [02:30<00:00, 274.14it/s]
# 100%|████████████████████████████████████| 41384/41384 [02:30<00:00, 274.22it/s]

# %%
df.to_csv('../dataset/cop_c_ratings.csv')

# %%
df_cop = pd.read_csv('../dataset/cop_c_ratings.csv')
df_cop.drop('Unnamed: 0', axis=1, inplace=True)
df_cop
# Out:
#               cust cop_c     br_c  chnl_dv     de_dt  de_hr  buy_am  ratings
# 0       M839993508   B01  B010012        1  20211026     12       3      7.1
# 1       M839993508   B01  B010012        1  20211106     10       3      8.0
# 2       M839993508   B01  B010012        1  20210211     12       3      7.3
# 3       M839993508   B01  B010012        1  20210920     10       3      7.8
# 4       M839993508   D01  D010614        1  20211010      9       1      1.5
# ...            ...   ...      ...      ...       ...    ...     ...      ...
# 248299  M058650684   C02  C020002        1  20211116     14       1      9.1
# 248300  M058650684   C02  C020002        1  20211116     19       3      9.7
# 248301  M014154595   C01  C010087        2  20211212      9       1      9.1
# 248302  M510878172   C01  C010007        2  20211127     19       1      9.4
# 248303  M761634870   C01  C010014        2  20211224     19       3      9.4
#
# [248304 rows x 8 columns]

# %%
df_product = pd.read_csv('../dataset/df_merge_02_04_ratings.csv')
df_product.drop('Unnamed: 0', axis=1, inplace=True)
df_product
# Out:
#                cust cop_c     br_c    pd_c  de_hr  buy_ct    pd_nm  \
# 0        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 1        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 2        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 3        M430112881   A01  A010039  PD0290     10       1    남성티셔츠
# 4        M506355556   A01  A010032  PD0290     15       1    남성티셔츠
# ...             ...   ...      ...     ...    ...     ...      ...
# 3953237  M033482606   A05  A050003  PD0075     20       1  혈당계/혈압계
# 3953238  M489266563   A05  A050426  PD1221     15       1  청소기/광택기
# 3953239  M296090374   A05  A050260  PD0543     11       1      이발기
# 3953240  M560002381   A05  A050039  PD0543     12       1      이발기
# 3953241  M203801534   A05  A050178  PD0281     18       1     기타보험
#
#         clac_hlv_nm clac_mcls_nm  ratings
# 0              남성의류       남성의류상의      5.0
# 1              남성의류       남성의류상의      5.0
# 2              남성의류       남성의류상의      5.0
# 3              남성의류       남성의류상의      5.0
# 4              남성의류       남성의류상의      9.7
# ...             ...          ...      ...
# 3953237        건강용품       건강측정용품      1.1
# 3953238       자동차용품         세차용품      0.0
# 3953239     생활/주방가전        이미용가전      0.4
# 3953240     생활/주방가전        이미용가전      0.0
# 3953241    금융/보험서비스           보험      0.0
#
# [3953242 rows x 10 columns]

# %%
df_cop['de_dt'] = df_cop['de_dt'].astype('int64')
df_cop['de_dt'] = df_cop['de_dt'].astype('str')
df_cop.dropna(axis=0, inplace=True)
df_cop
# Out:
#               cust cop_c     br_c  chnl_dv     de_dt  de_hr  buy_am  ratings
# 0       M839993508   B01  B010012        1  20210101     12       3      7.1
# 1       M839993508   B01  B010012        1  20210101     10       3      8.0
# 2       M839993508   B01  B010012        1  20210101     12       3      7.3
# 3       M839993508   B01  B010012        1  20210101     10       3      7.8
# 4       M839993508   D01  D010614        1  20210101      9       1      1.5
# ...            ...   ...      ...      ...       ...    ...     ...      ...
# 248299  M058650684   C02  C020002        1  20210513     14       1      9.1
# 248300  M058650684   C02  C020002        1  20210513     19       3      9.7
# 248301  M014154595   C01  C010087        2  20210513      9       1      9.1
# 248302  M510878172   C01  C010007        2  20210513     19       1      9.4
# 248303  M761634870   C01  C010014        2  20210513     19       3      9.4
#
# [248249 rows x 8 columns]

# %%
weather_df = pd.read_csv('../dataset/weather.csv', encoding='euc-kr', skiprows=6)
weather_df['날짜'] = weather_df['날짜'].astype('str')
weather_df['날짜'] = weather_df['날짜'].str.replace(pat=r'-',repl=r'',regex=True)
weather_df['날짜'].astype('int64')

weather_df = weather_df.rename(columns={'날짜' : 'de_dt', '평균기온(℃)': '평균기온'})
weather_df.drop(columns=['지점', '최저기온(℃)', '최고기온(℃)'], axis=1, inplace=True)
weather_df
# Out:
#         de_dt  평균기온
# 0    20210101  -3.4
# 1    20210102  -2.8
# 2    20210103  -3.3
# 3    20210104  -2.0
# 4    20210105  -2.2
# ..        ...   ...
# 360  20211227  -4.6
# 361  20211228   0.0
# 362  20211229   2.5
# 363  20211230  -0.7
# 364  20211231  -3.9
#
# [365 rows x 2 columns]

# %%
df_cop = pd.merge(df_cop, weather_df, on='de_dt')
df_cop
# Out:
#               cust cop_c     br_c  chnl_dv     de_dt  de_hr  buy_am  ratings  \
# 0       M839993508   B01  B010012        1  20210101     12       3      7.1
# 1       M839993508   B01  B010012        1  20210101     10       3      8.0
# 2       M839993508   B01  B010012        1  20210101     12       3      7.3
# 3       M839993508   B01  B010012        1  20210101     10       3      7.8
# 4       M839993508   D01  D010614        1  20210101      9       1      1.5
# ...            ...   ...      ...      ...       ...    ...     ...      ...
# 248244  M058650684   C02  C020002        1  20210513     14       1      9.1
# 248245  M058650684   C02  C020002        1  20210513     19       3      9.7
# 248246  M014154595   C01  C010087        2  20210513      9       1      9.1
# 248247  M510878172   C01  C010007        2  20210513     19       1      9.4
# 248248  M761634870   C01  C010014        2  20210513     19       3      9.4
#
#         평균기온
# 0       -3.4
# 1       -3.4
# 2       -3.4
# 3       -3.4
# 4       -3.4
# ...      ...
# 248244  19.6
# 248245  19.6
# 248246  19.6
# 248247  19.6
# 248248  19.6
#
# [248249 rows x 9 columns]

# %%
import preprocessing as pre

# %%
df_02 = pd.merge(df_02, df_04, on='pd_c')
df_02
# Out:
#                cust        rct_no  chnl_dv cop_c     br_c    pd_c     de_dt  \
# 0        M430112881  A01000001113        1   A01  A010039  PD0290  20210101
# 1        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 2        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 3        M430112881  A01000004946        1   A01  A010039  PD0290  20210101
# 4        M506355556  A01000107137        1   A01  A010032  PD0290  20210101
# ...             ...           ...      ...   ...      ...     ...       ...
# 4381738  M696533418  E06045892016        2   A06      NaN  PD0520  20211115
# 4381739  M696533418  E06045892016        2   A06      NaN  PD0520  20211115
# 4381740  M111856694  E06045887405        2   A06      NaN  PD0520  20211118
# 4381741  M001808316  E06045891296        2   A06      NaN  PD0520  20211118
# 4381742  M475857646  E06046013307        2   A06      NaN  PD0520  20211121
#
#          de_hr    buy_am  buy_ct     pd_nm clac_hlv_nm clac_mcls_nm
# 0           10   15000.0       1     남성티셔츠        남성의류       남성의류상의
# 1           10   19000.0       1     남성티셔츠        남성의류       남성의류상의
# 2           10   19000.0       1     남성티셔츠        남성의류       남성의류상의
# 3           10   19000.0       1     남성티셔츠        남성의류       남성의류상의
# 4           15  199000.0       1     남성티셔츠        남성의류       남성의류상의
# ...        ...       ...     ...       ...         ...          ...
# 4381738      0    9900.0       1  자동차/레저렌탈    생활/렌탈서비스        렌탈서비스
# 4381739      0    9900.0       1  자동차/레저렌탈    생활/렌탈서비스        렌탈서비스
# 4381740      0     100.0       1  자동차/레저렌탈    생활/렌탈서비스        렌탈서비스
# 4381741      0     100.0       1  자동차/레저렌탈    생활/렌탈서비스        렌탈서비스
# 4381742      3     100.0       1  자동차/레저렌탈    생활/렌탈서비스        렌탈서비스
#
# [4381743 rows x 13 columns]

# %%
import multiprocessing as mp

# %%
def parallel_dataframe(df, func, cores):
    df_split = np.array_split(df, cores)
    pool = mp.Pool(cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    
    return df

# %%
def convert_rating(cust, clac_hlv_nm, df):
    cust = cust
    clac_hlv_nm = clac_hlv_nm

    try:
        pd_c = df[df['cust'] == cust][['clac_hlv_nm', 'buy_ct']]
        pd_c = pd_c.groupby('clac_hlv_nm')['buy_ct'].sum().reset_index()
        pd_c = pd_c.sort_values(by='buy_ct', ascending=False, ignore_index=True)

        pd_c['buy_ct'] = (pd_c['buy_ct'] - pd_c['buy_ct'].min()) / (pd_c['buy_ct'].max() - pd_c['buy_ct'].min())
        pd_c['buy_ct'][0] = random.uniform(0.90, 1.01) 
        pd_c['buy_ct'] = np.round(pd_c['buy_ct'], 3) * 10

        res = float(pd_c[pd_c['clac_hlv_nm'] == clac_hlv_nm]['buy_ct'])
        
    except: ValueError
        
    return res

def make_ratings1(data):
    data['ratings'] = data[:100].progress_apply(lambda x : convert_rating(x['cust'], x['clac_hlv_nm'], data), axis=1)
    return data

# %%
convert_rating(df_02['cust'][1], df_02['clac_hlv_nm'][1], df_02)
# Out:
# 0.97

# %%
convert_rating(df_02['cust'][1], df_02['clac_hlv_nm'][1], df_02)
# Out:
# 2.7600000000000002

# %%
df_02_ratings = parallel_dataframe(df_02[:100], make_ratings, 6)

# %%
df_02_ratings = parallel_dataframe(df_02, make_ratings, 6)
# Out:
# 100%|████████████████████████████████████| 16667/16667 [01:31<00:00, 182.26it/s]
# 100%|████████████████████████████████████| 16666/16666 [01:31<00:00, 181.92it/s]
# 100%|████████████████████████████████████| 16667/16667 [01:31<00:00, 181.41it/s]
# 100%|████████████████████████████████████| 16667/16667 [01:31<00:00, 181.17it/s]
# 100%|████████████████████████████████████| 16666/16666 [01:32<00:00, 180.83it/s]
# 100%|████████████████████████████████████| 16667/16667 [01:32<00:00, 180.74it/s]

# %%
df_02_ratings['ratings'].unique()
# Out:
# array([ 9.2 ,  9.26,  9.77,  9.29,  9.87,  9.03,  9.16,  9.04,  9.56,
#         9.72,  9.19,  9.85,  9.49,  9.78, 10.06,  9.36,  9.06,  9.86,
#         9.95,  9.46,  9.39,  9.5 ,  9.37,  9.75,  9.83,  9.99,  9.02,
#        10.02,  9.23,  9.61,  9.54,  9.44, 10.09,  9.73,  9.3 , 10.1 ,
#         9.88,  9.08, 10.  ,  9.68,  9.33,  9.63,  9.8 ,  9.62,  9.64,
#         9.97,  9.92,  9.31,  9.12,  9.53,  9.15,  9.05,  9.25, 10.08,
#         9.35,  9.81,  9.13, 10.01,  9.57, 10.03, 10.05,  9.07,  9.66,
#         9.7 ,  9.43,  9.55,  9.76,  9.67,  9.09, 10.07,  9.41,  9.21,
#         9.93,  9.91,  9.24,  9.32,  9.59,  9.52,  9.84,  9.98,  9.1 ,
#         9.48,  9.42,  9.01,  9.34,  9.28,  9.38,  9.74,  9.4 ,  9.27,
#         9.9 ,  9.47,  9.65,  9.14,  0.  ,  9.51,  9.22,  9.69,  9.18,
#         9.71,  9.96, 10.04,  9.58,  9.17,  9.11,  9.45,  9.94,  9.79,
#         9.  ,  9.89,  9.82,  9.6 ,   nan,  5.  ,  4.17,  3.33,  3.04,
#         0.85,  6.67,  3.64,  0.59,  2.22,  0.18,  2.  ,  1.67,  0.83,
#         0.61,  4.  ,  6.  ,  2.86,  2.5 ,  5.56,  3.75])

# %%
df_02.to_csv('../dataset/df_02_ratings.csv')

# %%
df_product = parallel_dataframe(df_merge_02_04, make_ratings)
# Out:
#                cust        rct_no  chnl_dv cop_c     br_c    pd_c     de_dt  \
# 0        M430112881  A01000001113        1   A01  A010039  PD0290  20210101
# 1        M646853852  A01000002265        1   A01  A010025  PD1369  20210101
# 2        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 3        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 4        M430112881  A01000004946        1   A01  A010039  PD0290  20210101
# ...             ...           ...      ...   ...      ...     ...       ...
# 4381738  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381739  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381740  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381741  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381742  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
#
#          de_hr   buy_am  buy_ct
# 0           10  15000.0       1
# 1           10  79700.0       1
# 2           10  19000.0       1
# 3           10  19000.0       1
# 4           10  19000.0       1
# ...        ...      ...     ...
# 4381738     23  50000.0       1
# 4381739     23  50000.0       1
# 4381740     23  50000.0       1
# 4381741     23  50000.0       1
# 4381742     23  50000.0       1
#
# [4381743 rows x 10 columns]
